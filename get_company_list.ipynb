# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl as ox

# %%
path= r'C:\Users\stox1\Desktop\업무\자료수집\factor_model'

year = 2008
company_list = []

for i in range(2008, 2019):
    df = pd.read_excel(path+'/'+str(i)+'_F.xlsx', index_col='Code')
    df['상장일']=pd.to_datetime(df['상장일'], format='%Y%m%d')
    code_data = df['Name']
    company_list.append(code_data)

# %%
company_codes = pd.DataFrame(company_list)

# %%
KSE_all_company_code = company_codes.columns.unique()
all_codes_list = KSE_all_company_code.values.tolist()

# %%
pd.DataFrame(all_codes_list, columns=['Code']).to_excel('전상장기업_코드리스트_since_2008_FF.xlsx')

# %%
col_names = np.array(range(2008, 2019)).tolist()
# Out:
# [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
all_codes_list
# Out:
# ['A000020',
#  'A000040',
#  'A000050',
#  'A000060',
#  'A000070',
#  'A000100',
#  'A000120',
#  'A000140',
#  'A000150',
#  'A000180',
#  'A000210',
#  'A000220',
#  'A000230',
#  'A000240',
#  'A000250',
#  'A000270',
#  'A000300',
#  'A000320',
#  'A000360',
#  'A000370',
#  'A000390',
#  'A000400',
#  'A000420',
#  'A000430',
#  'A000440',
#  'A000470',
#  'A000480',
#  'A000490',
#  'A000500',
#  'A000520',
#  'A000540',
#  'A000590',
#  'A000610',
#  'A000640',
#  'A000650',
#  'A000660',
#  'A000670',
#  'A000680',
#  'A000700',
#  'A000720',
#  'A000760',
#  'A000790',
#  'A000800',
#  'A000810',
#  'A000830',
#  'A000850',
#  'A000860',
#  'A000880',
#  'A000890',
#  'A000910',
#  'A000950',
#  'A000970',
#  'A000990',
#  'A001000',
#  'A001020',
#  'A001040',
#  'A001060',
#  'A001070',
#  'A001080',
#  'A001120',
#  'A001130',
#  'A001140',
#  'A001190',
#  'A001200',
#  'A001210',
#  'A001230',
#  'A001250',
#  'A001260',
#  'A001270',
#  'A001290',
#  'A001300',
# ...
